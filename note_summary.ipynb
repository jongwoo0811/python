# %% [markdown]
# ## 1주차 정리
# #### 변수
# 1. 메모리에 데이터를 저장하는 공간의 이름
# 2. 데이터들의 종류
#     - string
#     - int
#     - float
#     - bool
#     - tuple(수정 불가능)
#     - list(수정 가능)
#     - dict(key와 values의 형태)
# 3. python의 특징-> 변수를 생성할 때 데이터의 타임을 미리 지정하지 않아도 된다.
#     - python에서 자동으로 데이터 타입을 지정

# %% [markdown]
# #### 연산자
# 1. 일반적인 사칙연산
#     - +(덧셈) -(뺄셈) *(곱셈) /(나눗셈) //(몫) %(나머지) **(제곱)
# 2. 대입연산자
#     -  +=, -=, *=, /=, //=, %=, **=
# 3. 비교연산자
#     - 두개의 값을 비교하여 참/ 거짓의 형태로 출력
#     - 주로 사용되는 곳은 조건문, 반복문에서 사용
#     - ==(같다) !=(다르다) >(값이 한쪽이 더 크다) >= < <=
#     - 비교를 해야되는 조건이 2개 이상인 경우
#         - 두 조건이 모두 참이여야 참 : and (&)
#         - 두 조건 중 하나만 참이어도 참 : or (|)
#         - 부정의 표현으로 참을 거짓으로 거짓을 참으로 출력 : not(!,~)

# %% [markdown]
# #### 조건문
# 1. 특정한 조건에 맞춰서 컴퓨터에게 지시를 내리기 위한 방법
# 2. 조건식이 참인 경우 실행 할 코드를 작성
# 3. 조건식이 거짓인 경우 실행 할 코드를 작성
# 4. python특징 : 일반적인 프로그래밍 언어에서는 {}이용하여 실행 할 코드를 작성하는데 python에서는 들여쓰기를 이용하여 실행 할 코드를 작성

# %%
# 대입 연산자
 +=, -=, *=, /=, //=, %=, **=
x += 1      # x = x + 1
print(x) 

# 비교 연산자
print(x == y) 

 and, or, not
# and : 두 조건이 모두 참인 경우에 참 나머지의 경우는 모두 거짓
# or : 두 조건중 하나만 참이면 참을 출력, 두 조건이 모두 거짓인 경우에만 거짓을 출력
# not : True는 False로 False는 True로 출력

# %% [markdown]
# #### 반복문
# 1.  for문
#     - for 변수명 in range(시작값, 종료값, 증가값)
#     - for 변수명 in (list형태의 데이터)
#     - 리스트의 길이만큼 반복
#     - 리스트의 항복 하나 하나씩 변수에 담아서 아래의 코드를 실행
# 2. while문
#     - 초기값을 미리 지정
#     - while 조건식을 미리 지정하여 조건식이 거짓이 될 때 까지 반복 실행
#
# 3. 반복문은 무한 반복이 되지 않도록 조건을 맞춰서 사용하여야 한다.

# %%
# if문
score = int(input("점수를 입력하시오 "))

if score >= 90:
    print('A')
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
else : 
    print("F")

print("프로그램 종료")

# range(시작값, 종료값, 증가값)

# while문

# 초기값 지정
i = 0

while i < 10:
    i += 1
    print(i)

# continue, break
# continue 반복문으로 돌아간다. 
# break 반복문 종료

# %% [markdown]
# #### tuple & list & dict
# 1. tuple
#     - 여러 형태의 데이터를 담아두는 데이터 형태
#     - 가장 기본적인 형태
#     - 각 항목을 추가, 삭제 수정이 불가능
#     - ()묶어서 표기
# 2. list
#     - tuple과 매우 흡사
#     - 항목들을 추가, 삭제 , 수정이 가능 (list에 있는 내장함수를 이용)
#     - []로 묶어서 사용
# 3. dict
#     - 사전형 데이터를 의미
#     - key:value 의 쌍으로 이루어진 데이터의 형태
#     - list와는 달리 위치의 상관없이 원하는 데이터의 key값을 이용하여 출력이 가능

# %%
# 리스트 3 찾기
a = [1,2,3,4]
find_3 = 3

if find_3 in a:
    print(True)
else:
    print(False)

3 in a

for i in a:
    if i == 3:
        result = True
# Out:
# True

# %%
# 튜플

# 2번째 원소부터 4번째 원소까지 출력
print(a[1 : 4])
print(a[1:])    # 2번째부터 마지막까지 출력
print(a[:3])    # 처음부터 3번째 항목까지 출력

# %%
# 리스트 list[]

# a 리스트의 순서를 오름차순으로 변경
a.sort()
# b 리스트는 순서를 역순으로 변경
b.reverse()
# a 리스트에서 마지막 항목 삭제
a.pop()
# b 리스트에는 22라는 항목을 마지막 항에 추가 
b.append(22)

# %%
# 딕셔너리 dict {}

# 사전형 데이터
# {key1 : value1, key2 : value2, ...}
dict = {'name' : 'test', 'age' : 20, 'phone' : "01012345678"}

# 새로운 키 : 벨류 를 추가 
# 새로운 키값은 입력 
dict['area'] = 'seoul'

# 기존의 키 값에 있는 벨류를 수정
dict['age'] = 30

# 키 값을 삭제
del(dict['phone'])

# %% [markdown]
# #### 함수
# 1. 고정된 데이터를 저장하는게 변수라면 함수를 행동을 저장한다.
# 2. def 키워드를 이용하여 함수 생성
# 3. 함수를 호출하는 경우에는 함수명(인자)
# 4. 일반적인 경우에는 함수의 매개변수의 개수와 인자의 개수가 같아야한다

# %%
# 비어있는 리스트 하나 생성
# 함수 생성
# 매개변수 1개, 받아온 인자값을 비어있는 리스트에 추가
# 조건 : 리스트 안에 인자값이 존재하면 추가하지 않는다. 존재하지 않으면 추가
# input()함수를 이용하여 2번 과정에서 만든 함수를 호출, 인자 값으로 input에서 받아온 데이터를 사용

_list =[]

# %%
def func_2(x):
    if x not in _list:
        _list.append(x):
    else:
        print("리스트에 값이 존재한다")
    return"함수종료"

# %%
# 함수

# 문자의 길이를 출력해주는 함수
print(len(a))

# 문자를 모두 대문자로 변경
print(a.upper())
# 문자를 모두 소문자로 변경
print(a.lower())
# 단어의 첫글자만 대문자로 변경 함수
print(b.title())

#  좌우의 공백을 제거하는 함수
# strip()
a.lstrip()
a.rstrip()

# 특정한 단어를 대체하는 함수 
# replace(기준 단어, 대체할 단어)

# b 변수의 '$' 표기를 '-' 변경
b.replace('$', '-')

# a 변수에 공백을 모두 삭제하려면?
a.replace(" ", "")

# split(특정한 값)-> 인자 값을 아무것도 넣지 않으면 " "을 기준으로 나눠준다

# max() -> 인자값들 중에 가장 큰 숫자를 출력
# min() -> 인자 값들 중에 가장 작은 숫자를 출력

# 일반함수

# 매개변수가 존재하지 않는 경우
# 함수 선언, 생성
def func_1():
    return "Hello"

# 매개변수가 존재하는 경우
def func_2(a, b):
    c = a + b
    return c

# %% [markdown]
# #### 외부 라이브러리
# 1. 함수, 클래스들의 집합체
# 2. 라이브러리 설치
#     - !pip install 라이브러리명
# 3. 라이브러리 로드
#     - import 라이브러리명 as 별칭
#     - from 라이브러리명 import (라이브러리 내부의 기능)

# %%
# 클래스

# %% [markdown]
# #### pandas
# 1. 외부의 파일을 가지고 오는 함수
#     - read_csv(파일의 경로, encoing="인코더 종류(utf-8, euc-kr,cp949")), json, excel
# 2. 데이터프레임에서 컬럼의 이름을 변경하는 방법
#     - 데이터프레임명.columns = [변경할 컬럼들의 리스트 항목]
# 3. 데이터프레임에서 특정 컬럼을 추출하는 방법?
#     - 단일 컬럼을 추출하는 방법 =데이터프레임명[컬럼명] -> 스리즈
#     - 여러개의 컬럼을 추출 : 데이터프레임명[['컬럼1','컬럼2']]->데이터프레임
# 4. 스리즈 형태의 데이터를 리스트 형태로 변환?
#     - 스리즈명.tolist()
# 5. 컬럼의 값을 기준으로 정렬을 변경하는 함수?
#     - sort_values(기준이 되는 컬럼)
#     - ascending : 오름차순, 내림차순 지정
#     - inplace : 기준이 되는 데이터프레임을 변경할지 지정(기본값 : False)
# 6. 인덱스를 재지정하는 함수?
#     - reset_index()
#     - drop : 기존의 인덱스를 삭제 할지 지정(기본값 : False)
#     - inplace가 존재한다
# 7. 결측치를 유무 판단
#     - isna(): 결측치인가를 판단하여 참/거짓형태로 출력
#     - isna().sum() : 컬럼별 결측치의 개수를 확인
#     - 결측치에 값을 치환 : fillna(n) -> n의 값으로 결측치를 치환
# 8.  그룹화 함수
#     - groupby(그룹화할 컬럼명)
#     - sum(): 그룹화 한 데이터들의 합계
#     - mean() : 그룹화 한 데이터들의 평균
#     - max, min() : 데이터들의 최솟값, 최대값
#     - count() : 데이터의 개수
#     - agg() : 데이터들의 연산을 한줄로 처리하기 위한 함수
# 9. 데이터프레임에 통계요약 정보를 출력하는 함수?
#     - describe()
# 10. 데이터 간의 차이를 구하는 함수
#     - diff(n) 현재의 행의 데이터와 n만큼 이동한 데이터간의 차이를 출력
# 11. 행을 이동하는 함수?
#     - shift(n)
#     - 행을 n만큼 이동한 데이터의 값을출력
# 12. 데이터프레임간의 결합 함수
#     - concat() 단순하게 열이나 행을 결합하는 합수
#         - axis: 행을 결합할지 열을 결합할지 지정
#     - merge() 특정한 조건에 맞춰서 열을 추가해주는 함수
#         -   SQL에 있는 join과 흡사
#         - on: 특정한 조건
#         - how : 기준이 되는 데이터프레임을 지정(left, right ,outer, inner)
# 13. apply()
#     - 데이터프레임에 있는 각 원소들을 ()안에 함수에 대입하여 실행
#     - ex) apply(일반함수), apply(lambda 함수)
# 14. 시계열 변환
#     -to_datetime(변경할 데이터, format="")
#     -format : 변경할 데이터의 형태

# %%
# 판다스

# 스리즈 형태 데이터를 생성
pd_list = pd.Series([1,2,3,4],index=['a','b','C','D'])


#데이터 프레임 생성
_value = [[1,2,3],[4,5,6],[7,8,9]]
_index = ['a','b','c']
_column = ['A','B','C']
df= pd.DataFrame(_value,index = _index, columns = _column)

# 파일로드
pd.read_csv("../csv/corona.csv")
# 절대 경로로 파일의 위치를 지정
pd.read_csv("C:\\Users\\bjw\\Documents\\test_\\csv\\corona.csv")

# is()라는 함수를 사용하여 결측치를 확인
# isna()함수사용
df.isna().sum()

# 결측치를 제거
# dropna는 결측치를 제거하는 함수
df.dropna(axis=0) # 결측치가있는 행 전부 삭제

# 결측치를 'OT'로 대체
drinks.loc[(drinks['continent].isna()),'continent] = 'OT'


# 데이터 프레임 필터 기능 
# loc[행의 조건,열의 조건] , location의 약자
# iloc[행의 위치, 열의 위치]
sales.iloc[1:3, 1:3]

# unnamed: 0 컬럼을 삭제
corona = corona.drop("Unnamed: 0", axis =1)

# 컬럼의 이름을 변경
# 컬럼 변수를 출력
corona.columns = ["등록일시"]

# 데이터프레임에 정렬을 변경하는 함수
# sort_values()
corona.sort_values('등록일시', ascending= True, inplace =True)

# 일일사망자 파생변수를 생성
corona['일일사망자'] =corona['누적사망자'] - corona['누적사망자']


# 그룹화 함수
# groupby()
# 인자 값 : 특정 컬럼을 지정
group_data = sales.groupby(['권역','국가']).sum()


# 시계열 데이터로 데이터의 형태를 변경
# pd.to_datetime(변경할 데이터, format = "")
t = '04/05/05'
pd.to_datetime(t, format="%y/%m/%d")

# 원본데이터를 생성
origin_data = uriage.copy()

# upper(): 문자열을 모두 대문자로 변환
# str.upper() 사용하여 문자열을 대문자로 변경하는 방식  

# concat()함수를 이용하여 데이터프레임을 결합
# 단순하게 행을 추가
#pd.concat([df, df2], axis = 0, ignore_index=True) / axis= 0 or "rows"
                    # or
pd.concat([df, df2], axis = 0).reset_index(drop =True)

pd.merge(df, df2, on = 'id')
# on = left 왼쪽 기준으로 분류
    #= right 오른쪽 기준으로 분류
    #= inner 두 조건의 교집합
    #= outer 두 조건의 외집합

#원하는 나라 순위를 찾아보자
drinks_rank.loc[drinks_rank['country']=='South Korea']

# %%
# 시각화

# matplotlib as plt

# plt.scatter(x,y,s = area, c=color, alpha=0.6)
# s = scale 크기 / c= 색 alpha는 투명도

# 히트맵 출력
cols_view =['beer','spirit','wine','alcohol']
sns.set(font_scale =1.5)#글자 크기 키워주는 코드
hm=sns.heatmap(corr.values,cbar=True, annot = True,square = True, fmt = '.2f', annot_kws={'size':20},xticklabels=cols_view,yticklabels=cols_view)
plt.tight_layout()
plt.show()
# cbar 사이드 바
# annot 히트맵 숫자 표시
# square 정사각형 여부
# fmt 소수점 표시



# 우리나라를 그래프에서 표기
x = list(range(len(drinks_rank)))
y = drinks_rank['alcohol_rate']
# 국가리스트 생성
country_list = drinks_rank['country'].tolist()
bar_list = plt.bar(x,y)
korea_rank = country_list.index('South Korea')
korea_alcohol_rate = drinks_rank.loc[drinks_rank['country']== 'South Korea', 'alcohol_rate']
# 그래프커스텀 / 한국 표시하기
# South Korea만 색상 변경
bar_list[country_list.index('South Korea')].set_color('r')  # 여기서 index는 country_list에서 위치를 뜻함
# 그래프에 글씨와 화살표 추가
plt.annotate('South Korea :' + str(korea_rank + 1),\
              xy=(korea_rank, korea_alcohol_rate), xytext=(korea_rank+ 5, korea_alcohol_rate+0.03),arrowprops=dict(facecolor = 'r', shrink =0.01))
